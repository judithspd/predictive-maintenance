# %% [markdown]
# ## Visualization of the signals captured during 10 seconds.

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import statistics as stats
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
HA1 = sio.loadmat('H-A-1.mat')
channel1HA1 = HA1['Channel_1']
n = len(channel1HA1) # Número de muestras

canal1HA1 = channel1HA1.T[0]
f = 200000 # Hz #graba a 200000 por s
t = np.linspace(0, 10, n)
dt = t[1] - t[0]

HA2 = sio.loadmat('H-A-2.mat')
channel1HA2 = HA2['Channel_1']
canal1HA2 = channel1HA2.T[0]

HA3 = sio.loadmat('H-A-3.mat')
channel1HA3 = HA3['Channel_1']
canal1HA3 = channel1HA3.T[0]

# %%
HB1 = sio.loadmat('H-B-1.mat')
channel1HB1 = HB1['Channel_1']
canal1HB1 = channel1HB1.T[0]

HB2 = sio.loadmat('H-B-2.mat')
channel1HB2 = HB2['Channel_1']
canal1HB2 = channel1HB2.T[0]

HB3 = sio.loadmat('H-B-3.mat')
channel1HB3 = HB3['Channel_1']
canal1HB3 = channel1HB3.T[0]

# %%
HC1 = sio.loadmat('H-C-1.mat')
channel1HC1 = HC1['Channel_1']
canal1HC1 = channel1HC1.T[0]

HC2 = sio.loadmat('H-C-2.mat')
channel1HC2 = HC2['Channel_1']
canal1HC2 = channel1HC2.T[0]

HC3 = sio.loadmat('H-C-3.mat')
channel1HC3 = HC3['Channel_1']
canal1HC3 = channel1HC3.T[0]

# %%
HD1 = sio.loadmat('H-D-1.mat')
channel1HD1 = HD1['Channel_1']
canal1HD1 = channel1HD1.T[0]

HD2 = sio.loadmat('H-D-2.mat')
channel1HD2 = HD2['Channel_1']
canal1HD2 = channel1HD2.T[0]

HD3 = sio.loadmat('H-D-3.mat')
channel1HD3 = HD3['Channel_1']
canal1HD3 = channel1HD3.T[0]

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1HA1, 'b', alpha = 0.8, label = 'H-A-1')
plt.plot(t, canal1HA2, 'g', alpha = 0.8, label = 'H-A-2')
plt.plot(t, canal1HA3, 'r', alpha = 0.8, label = 'H-A-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1HB1, 'b', alpha = 0.8, label = 'H-B-1')
plt.plot(t, canal1HB2, 'g', alpha = 0.8, label = 'H-B-2')
plt.plot(t, canal1HB3, 'r', alpha = 0.8, label = 'H-B-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1HC1, 'b', alpha = 0.8, label = 'H-C-1')
plt.plot(t, canal1HC2, 'g', alpha = 0.8, label = 'H-C-2')
plt.plot(t, canal1HC3, 'r', alpha = 0.8, label = 'H-C-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1HD1, 'b', alpha = 0.8, label = 'H-D-1')
plt.plot(t, canal1HD2, 'g', alpha = 0.8, label = 'H-D-2')
plt.plot(t, canal1HD3, 'r', alpha = 0.8, label = 'H-D-3')
plt.legend()

# %%
IA1 = sio.loadmat('I-A-1.mat')
channel1IA1 = IA1['Channel_1']
canal1IA1 = channel1IA1.T[0]

IA2 = sio.loadmat('I-A-2.mat')
channel1IA2 = IA2['Channel_1']
canal1IA2 = channel1IA2.T[0]

IA3 = sio.loadmat('I-A-3.mat')
channel1IA3 = IA3['Channel_1']
canal1IA3 = channel1IA3.T[0]

# %%
IB1 = sio.loadmat('I-B-1.mat')
channel1IB1 = IB1['Channel_1']
canal1IB1 = channel1IB1.T[0]

IB2 = sio.loadmat('I-B-2.mat')
channel1IB2 = IB2['Channel_1']
canal1IB2 = channel1IB2.T[0]

IB3 = sio.loadmat('I-B-3.mat')
channel1IB3 = IB3['Channel_1']
canal1IB3 = channel1IB3.T[0]

# %%
IC1 = sio.loadmat('I-C-1.mat')
channel1IC1 = IC1['Channel_1']
canal1IC1 = channel1IC1.T[0]

IC2 = sio.loadmat('I-C-2.mat')
channel1IC2 = IC2['Channel_1']
canal1IC2 = channel1IC2.T[0]

IC3 = sio.loadmat('I-C-3.mat')
channel1IC3 = IC3['Channel_1']
canal1IC3 = channel1IC3.T[0]

# %%
ID1 = sio.loadmat('I-D-1.mat')
channel1ID1 = ID1['Channel_1']
canal1ID1 = channel1ID1.T[0]

ID2 = sio.loadmat('I-D-2.mat')
channel1ID2 = ID2['Channel_1']
canal1ID2 = channel1ID2.T[0]

ID3 = sio.loadmat('I-D-3.mat')
channel1ID3 = ID3['Channel_1']
canal1ID3 = channel1ID3.T[0]

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1IA1, 'b', alpha = 0.8, label = 'I-A-1')
plt.plot(t, canal1IA2, 'g', alpha = 0.8, label = 'I-A-2')
plt.plot(t, canal1IA3, 'r', alpha = 0.8, label = 'I-A-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1IB1, 'b', alpha = 0.8, label = 'I-B-1')
plt.plot(t, canal1IB2, 'g', alpha = 0.8, label = 'I-B-2')
plt.plot(t, canal1IB3, 'r', alpha = 0.8, label = 'I-B-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1IC1, 'b', alpha = 0.8, label = 'I-C-1')
plt.plot(t, canal1IC2, 'g', alpha = 0.8, label = 'I-C-2')
plt.plot(t, canal1IC3, 'r', alpha = 0.8, label = 'I-C-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1ID1, 'b', alpha = 0.8, label = 'I-D-1')
plt.plot(t, canal1ID2, 'g', alpha = 0.8,label = 'I-D-1')
plt.plot(t, canal1ID3, 'r', alpha = 0.8, label = 'I-D-1')
plt.legend()

# %%
OA1 = sio.loadmat('O-A-1.mat')
channel1OA1 = OA1['Channel_1']
canal1OA1 = channel1OA1.T[0]

OA2 = sio.loadmat('O-A-2.mat')
channel1OA2 = OA2['Channel_1']
canal1OA2 = channel1OA2.T[0]

OA3 = sio.loadmat('O-A-3.mat')
channel1OA3 = OA3['Channel_1']
canal1OA3 = channel1OA3.T[0]

# %%
OB1 = sio.loadmat('O-B-1.mat')
channel1OB1 = OB1['Channel_1']
canal1OB1 = channel1OB1.T[0]

OB2 = sio.loadmat('O-B-2.mat')
channel1OB2 = OB2['Channel_1']
canal1OB2 = channel1OB2.T[0]

OB3 = sio.loadmat('O-B-3.mat')
channel1OB3 = OB3['Channel_1']
canal1OB3 = channel1OB3.T[0]

# %%
OC1 = sio.loadmat('O-C-1.mat')
channel1OC1 = OC1['Channel_1']
canal1OC1 = channel1OC1.T[0]

OC2 = sio.loadmat('O-C-2.mat')
channel1OC2 = OC2['Channel_1']
canal1OC2 = channel1OC2.T[0]

OC3 = sio.loadmat('O-C-3.mat')
channel1OC3 = OC3['Channel_1']
canal1OC3 = channel1OC3.T[0]

# %%
OD1 = sio.loadmat('O-D-1.mat')
channel1OD1 = OD1['Channel_1']
canal1OD1 = channel1OD1.T[0]

OD2 = sio.loadmat('O-D-2.mat')
channel1OD2 = OD2['Channel_1']
canal1OD2 = channel1OD2.T[0]

OD3 = sio.loadmat('O-D-3.mat')
channel1OD3 = OD3['Channel_1']
canal1OD3 = channel1OD3.T[0]

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1OA1, 'b', alpha = 0.8, label = 'O-A-1')
plt.plot(t, canal1OA2, 'g', alpha = 0.8, label = 'O-A-2')
plt.plot(t, canal1OA3, 'r', alpha = 0.8, label = 'O-A-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1OB1, 'b', alpha = 0.8, label = 'O-B-1')
plt.plot(t, canal1OB2, 'g', alpha = 0.8, label = 'O-B-2')
plt.plot(t, canal1OB3, 'r', alpha = 0.8, label = 'O-B-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1OC1, 'b', alpha = 0.8, label = 'O-C-1')
plt.plot(t, canal1OC2, 'g', alpha = 0.8, label = 'O-C-2')
plt.plot(t, canal1OC3, 'r', alpha = 0.8, label = 'O-C-3')
plt.legend()

# %%
fig = plt.figure(figsize=(10,6))
plt.plot(t, canal1OD1, 'b', alpha = 0.8, label = 'O-D-1')
plt.plot(t, canal1OD2, 'g', alpha = 0.8, label = 'O-D-2')
plt.plot(t, canal1OD3, 'r', alpha = 0.8, label = 'O-D-3')
plt.legend()

# %%
fig, ax = plt.subplots(2, 2)
fig.set_size_inches(18,8)
ax[0, 0].plot(t, canal1OA1, 'b', alpha = 0.8, label = 'O-A-1')
ax[0, 0].plot(t, canal1OA2, 'g', alpha = 0.8, label = 'O-A-2')
ax[0, 0].plot(t, canal1OA3, 'r', alpha = 0.8, label = 'O-A-3')
ax[0, 0].legend(loc="upper left")
ax[0, 1].plot(t, canal1OB1, 'b', alpha = 0.8, label = 'O-B-1')
ax[0, 1].plot(t, canal1OB2, 'g', alpha = 0.8, label = 'O-B-2')
ax[0, 1].plot(t, canal1OB3, 'r', alpha = 0.8, label = 'O-B-3')
ax[0, 1].legend(loc="upper right")
ax[1, 0].plot(t, canal1OC1, 'b', alpha = 0.8, label = 'O-C-1')
ax[1, 0].plot(t, canal1OC2, 'g', alpha = 0.8, label = 'O-C-2')
ax[1, 0].plot(t, canal1OC3, 'r', alpha = 0.8, label = 'O-C-3')
ax[1, 0].legend(loc="upper left")
ax[1, 1].plot(t, canal1OD1, 'b', alpha = 0.8, label = 'O-D-1')
ax[1, 1].plot(t, canal1OD2, 'g', alpha = 0.8, label = 'O-D-2')
ax[1, 1].plot(t, canal1OD3, 'r', alpha = 0.8, label = 'O-D-3')
ax[1, 1].legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
fig.set_size_inches(18,8)
ax[0, 0].plot(t, canal1HA1, 'b', alpha = 0.8, label = 'H-A-1')
ax[0, 0].plot(t, canal1HA2, 'g', alpha = 0.8, label = 'H-A-2')
ax[0, 0].plot(t, canal1HA3, 'r', alpha = 0.8, label = 'H-A-3')
ax[0, 0].legend(loc="upper left")
ax[0, 1].plot(t, canal1HB1, 'b', alpha = 0.8, label = 'H-B-1')
ax[0, 1].plot(t, canal1HB2, 'g', alpha = 0.8, label = 'H-B-2')
ax[0, 1].plot(t, canal1HB3, 'r', alpha = 0.8, label = 'H-B-3')
ax[0, 1].legend(loc="upper right")
ax[1, 0].plot(t, canal1HC1, 'b', alpha = 0.8, label = 'H-C-1')
ax[1, 0].plot(t, canal1HC2, 'g', alpha = 0.8, label = 'H-C-2')
ax[1, 0].plot(t, canal1HC3, 'r', alpha = 0.8, label = 'H-C-3')
ax[1, 0].legend(loc="upper left")
ax[1, 1].plot(t, canal1HD1, 'b', alpha = 0.8, label = 'H-D-1')
ax[1, 1].plot(t, canal1HD2, 'g', alpha = 0.8, label = 'H-D-2')
ax[1, 1].plot(t, canal1HD3, 'r', alpha = 0.8, label = 'H-D-3')
ax[1, 1].legend(loc="upper right")
plt.show()

# %%
fig, ax = plt.subplots(2, 2)
fig.set_size_inches(18,8)
ax[0, 0].plot(t, canal1IA1, 'b', alpha = 0.8, label = 'I-A-1')
ax[0, 0].plot(t, canal1IA2, 'g', alpha = 0.8, label = 'I-A-2')
ax[0, 0].plot(t, canal1IA3, 'r', alpha = 0.8, label = 'I-A-3')
ax[0, 0].set_xlabel('Frequency')
ax[0, 0].set_ylabel('Amplitude')
ax[0, 0].legend(loc="lower left")

ax[0, 1].plot(t, canal1IB1, 'b', alpha = 0.8, label = 'I-B-1')
ax[0, 1].plot(t, canal1IB2, 'g', alpha = 0.8, label = 'I-B-2')
ax[0, 1].plot(t, canal1IB3, 'r', alpha = 0.8, label = 'I-B-3')
ax[0, 1].set_xlabel('Frequency')
ax[0, 1].set_ylabel('Amplitude')
ax[0, 1].legend(loc="lower right")

ax[1, 0].plot(t, canal1IC1, 'b', alpha = 0.8, label = 'I-C-1')
ax[1, 0].plot(t, canal1IC2, 'g', alpha = 0.8, label = 'I-C-2')
ax[1, 0].plot(t, canal1IC3, 'r', alpha = 0.8, label = 'I-C-3')
ax[1, 0].set_xlabel('Frequency')
ax[1, 0].set_ylabel('Amplitude')
ax[1, 0].legend(loc="lower left")

ax[1, 1].plot(t, canal1ID1, 'b', alpha = 0.8, label = 'I-D-1')
ax[1, 1].plot(t, canal1ID2, 'g', alpha = 0.8, label = 'I-D-2')
ax[1, 1].plot(t, canal1ID3, 'r', alpha = 0.8, label = 'I-D-3')
ax[1, 1].set_xlabel('Frequency')
ax[1, 1].set_ylabel('Amplitude')
ax[1, 1].legend(loc="lower right")
plt.show()
