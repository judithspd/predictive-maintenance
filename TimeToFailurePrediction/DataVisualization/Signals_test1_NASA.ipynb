# %% [markdown]
# ### Visualization of the first 6 channels of test 1 NASA Bearing dataset.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.io as sio

# %%
signals_test2_channels = sio.loadmat('signals_test1.mat')
signals_test2_channels
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Tue Apr  6 10:35:20 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Ch1': array([[-0.022, -0.105, -0.183, ..., -0.193, -0.115, -0.042],
#         [-0.117, -0.132, -0.186, ..., -0.134, -0.212, -0.208],
#         [-0.054, -0.215, -0.242, ..., -0.066, -0.107, -0.107],
#         ...,
#         [-0.139, -0.098, -0.188, ...,  0.007, -0.039, -0.09 ],
#         [-0.344, -0.344, -0.146, ..., -0.183, -0.359, -0.281],
#         [-0.071, -0.066, -0.078, ..., -0.081, -0.115, -0.098]]),
#  'Ch2': array([[-0.039, -0.017, -0.098, ..., -0.303,  0.076,  0.098],
#         [-0.076, -0.068, -0.12 , ..., -0.081, -0.02 , -0.073],
#         [-0.049, -0.044, -0.112, ..., -0.042,  0.042, -0.054],
#         ...,
#         [-0.044, -0.178, -0.22 , ..., -0.232, -0.093, -0.063],
#         [ 0.046, -0.137, -0.225, ...,  0.09 ,  0.049,  0.01 ],
#         [-0.117, -0.068, -0.154, ..., -0.02 , -0.146, -0.166]]),
#  'Ch3': array([[-0.183, -0.164, -0.195, ..., -0.071, -0.078,  0.103],
#         [-0.127, -0.117, -0.217, ..., -0.217, -0.166, -0.203],
#         [-0.208, -0.151, -0.081, ..., -0.132, -0.095, -0.073],
#         ...,
#         [-0.366, -0.281, -0.291, ...,  0.063,  0.129, -0.107],
#         [ 0.083,  0.083, -0.107, ..., -0.12 , -0.117, -0.2  ],
#         [-0.295, -0.063, -0.193, ..., -0.325, -0.19 ,  0.012]]),
#  'Ch4': array([[-0.054, -0.183, -0.125, ..., -0.125, -0.332, -0.059],
#         [-0.144, -0.083, -0.212, ..., -0.059, -0.115, -0.176],
#         [-0.081, -0.149, -0.178, ...,  0.022, -0.054, -0.024],
#         ...,
#         [ 0.01 ,  0.037,  0.063, ..., -0.115, -0.12 , -0.232],
#         [-0.283, -0.3  , -0.193, ..., -0.017,  0.083,  0.   ],
#         [-0.471, -0.417, -0.122, ..., -0.049, -0.427, -0.552]]),
#  'Ch5': array([[-0.105, -0.049, -0.005, ..., -0.237, -0.027, -0.002],
#         [-0.083, -0.132, -0.081, ...,  0.056, -0.186, -0.049],
#         [-0.122, -0.244, -0.156, ..., -0.137, -0.247, -0.229],
#         ...,
#         [-0.593,  0.366, -0.393, ..., -0.173, -0.4  ,  0.505],
#         [ 0.107,  0.193, -0.176, ..., -0.166, -0.415,  0.046],
#         [ 0.132, -0.271, -0.254, ..., -0.112,  0.813, -0.071]]),
#  'Ch6': array([[-0.134,  0.029, -0.007, ..., -0.251, -0.002, -0.342],
#         [-0.002, -0.076, -0.112, ..., -0.107, -0.117, -0.068],
#         [-0.222, -0.142, -0.103, ..., -0.063,  0.005, -0.022],
#         ...,
#         [-0.144, -0.42 , -0.322, ..., -0.034, -0.862, -0.146],
#         [ 0.076, -0.73 ,  0.432, ...,  0.437,  0.417, -0.237],
#         [-0.144, -0.107, -0.154, ..., -0.481,  0.049,  0.588]])}

# %%
canal1 = signals_test2_channels['Ch1']
canal2 = signals_test2_channels['Ch2']
canal3 = signals_test2_channels['Ch3']
canal4 = signals_test2_channels['Ch4']
canal5 = signals_test2_channels['Ch5']
canal6 = signals_test2_channels['Ch6']
canal1 = canal1[0]
canal2 = canal2[0]
canal3 = canal3[0]
canal4 = canal4[0]
canal5 = canal5[0]
canal6 = canal6[0]
t =  np.linspace(0, 10 * len(canal1), len(canal1))

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2)
fig.set_size_inches(17, 15)
ax1.plot(t, canal1)
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax1.set_title('Ch1 - test1')

ax2.plot(t, canal2)
ax2.set_xlabel('Time')
ax2.set_ylabel('Amplitude')
ax2.set_title('Ch2 - test1')

ax3.plot(t, canal3)
ax3.set_xlabel('Time')
ax3.set_ylabel('Amplitude')
ax3.set_title('Ch3 - test1')

ax4.plot(t, canal4)
ax4.set_xlabel('Time')
ax4.set_ylabel('Amplitude')
ax4.set_title('Ch4 - test1')

ax5.plot(t, canal5)
ax5.set_xlabel('Time')
ax5.set_ylabel('Amplitude')
ax5.set_title('Ch5 - test1')

ax6.plot(t, canal6)
ax6.set_xlabel('Time')
ax6.set_ylabel('Amplitude')
ax6.set_title('Ch6 - test1')
# Out:
# Text(0.5, 1.0, 'Ch6 - test1')

# %%
fig.savefig("señales_test1.jpg")
