# %% [markdown]
# ### Visualization of the first 6 channels of test 1 NASA Bearing dataset.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.io as sio

# %%
signals_test1_channels = sio.loadmat('./DataSignals/signals_test1_channels.mat')
signals_test1_channels
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Thu May  6 09:36:24 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Ch1': array([[-0.022, -0.105, -0.183, ..., -0.081, -0.115, -0.098]]),
#  'Ch2': array([[-0.039, -0.017, -0.098, ..., -0.02 , -0.146, -0.166]]),
#  'Ch3': array([[-0.183, -0.164, -0.195, ..., -0.325, -0.19 ,  0.012]]),
#  'Ch4': array([[-0.054, -0.183, -0.125, ..., -0.049, -0.427, -0.552]]),
#  'Ch5': array([[-0.105, -0.049, -0.005, ..., -0.112,  0.813, -0.071]]),
#  'Ch6': array([[-0.134,  0.029, -0.007, ..., -0.481,  0.049,  0.588]])}

# %%
canal1 = signals_test1_channels['Ch1']
canal2 = signals_test1_channels['Ch2']
canal3 = signals_test1_channels['Ch3']
canal4 = signals_test1_channels['Ch4']
canal5 = signals_test1_channels['Ch5']
canal6 = signals_test1_channels['Ch6']
canal1 = canal1[0]
canal2 = canal2[0]
canal3 = canal3[0]
canal4 = canal4[0]
canal5 = canal5[0]
canal6 = canal6[0]
t =  np.linspace(0, 10 * len(canal1), len(canal1))

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2)
fig.set_size_inches(17, 15)
ax1.plot(t, canal1)
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax1.set_title('Ch1 - test1')

ax2.plot(t, canal2)
ax2.set_xlabel('Time')
ax2.set_ylabel('Amplitude')
ax2.set_title('Ch2 - test1')

ax3.plot(t, canal3)
ax3.set_xlabel('Time')
ax3.set_ylabel('Amplitude')
ax3.set_title('Ch3 - test1')

ax4.plot(t, canal4)
ax4.set_xlabel('Time')
ax4.set_ylabel('Amplitude')
ax4.set_title('Ch4 - test1')

ax5.plot(t, canal5)
ax5.set_xlabel('Time')
ax5.set_ylabel('Amplitude')
ax5.set_title('Ch5 - test1')

ax6.plot(t, canal6)
ax6.set_xlabel('Time')
ax6.set_ylabel('Amplitude')
ax6.set_title('Ch6 - test1')
# Out:
# Text(0.5, 1.0, 'Ch6 - test1')
