# %% [markdown]
# ### Visualization of the 4 channels of test 3 NASA Bearing dataset.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.io as sio

# %%
signals_test3_channels = sio.loadmat('../AnalisisTest2/signals_test3_channels.mat')
signals_test3_channels
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Tue Apr 13 11:04:39 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Ch1': array([[0.034, 0.103, 0.095, ..., 0.   , 0.002, 0.   ]]),
#  'Ch2': array([[ 0.264,  0.083, -0.039, ...,  0.002,  0.002,  0.002]]),
#  'Ch3': array([[ 0.039, -0.061, -0.007, ...,  0.005,  0.002,  0.005]]),
#  'Ch4': array([[-0.046, -0.012,  0.039, ...,  0.   ,  0.002,  0.   ]])}

# %%
canal1 = signals_test3_channels['Ch1']
canal2 = signals_test3_channels['Ch2']
canal3 = signals_test3_channels['Ch3']
canal4 = signals_test3_channels['Ch4']
canal1 = canal1[0]
canal2 = canal2[0]
canal3 = canal3[0]
canal4 = canal4[0]
t =  np.linspace(0, 10 * len(canal1), len(canal1))

# %%
len(canal1)
# Out:
# 129515520

# %%
plt.figure(figsize=(7,4))
plt.plot(t, canal1)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ch1 - test3')
# Out:
# Text(0.5, 1.0, 'Ch1 - test3')

# %%
plt.figure(figsize=(7,4))
plt.plot(t, canal2)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ch2 - test3')
# Out:
# Text(0.5, 1.0, 'Ch2 - test3')

# %%
plt.figure(figsize=(7,4))
plt.plot(t, canal3)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ch3 - test3')
# Out:
# Text(0.5, 1.0, 'Ch3 - test3')

# %%
plt.figure(figsize=(7,4))
plt.plot(t, canal4)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Ch4 - test3')
# Out:
# Text(0.5, 1.0, 'Ch4 - test3')
